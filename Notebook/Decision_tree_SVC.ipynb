# %%
# Importing libraries
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt 
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
# from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.naive_bayes import BernoulliNB
from sklearn.metrics import accuracy_score, confusion_matrix

# %%
# read data file
data=pd.read_csv('/config/workspace/Dataset/diabetes.csv')

# %%
data.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# min      0.000000                  0.078000   21.000000    0.000000
# 25%     27.300000                  0.243750   24.000000    0.000000
# 50%     32.000000                  0.372500   29.000000    0.000000
# 75%     36.600000                  0.626250   41.000000    1.000000
# max     67.100000                  2.420000   81.000000    1.000000

# %%
# checking null values
data.isnull().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
# replacing zero values with mean
data['BMI']=data['BMI'].replace(0, data['BMI'].mean())
data['BloodPressure']=data['BloodPressure'].replace(0, data['BloodPressure'].mean())
data['Glucose']=data['Glucose'].replace(0, data['Glucose'].mean())
data['Insulin']=data['Insulin'].replace(0, data['Insulin'].mean())
data['SkinThickness']=data['SkinThickness'].replace(0, data['SkinThickness'].mean())

# %%
# segregating dapendent and independent variables
X=data.drop(columns=['Outcome'])
y=data['Outcome']

# %%
# seperating train and test data
X_train, X_test, y_train, y_test= train_test_split(X,y, test_size=20, random_state=0)
X_test.shape, X_train.shape
# Out:
# ((20, 8), (748, 8))

# %%
# Desicion Tree Model Training with Hyperparameter tuining
import warnings
warnings.filterwarnings('ignore')

# %%
parameters={
    'criterion':['gini', 'entropy', 'log_loss'],
    'splitter':['best', 'random'],
    'max_depth':[1,2,3,4,5],
    'max_features':['auto', 'sqrt', 'log2']
}

# %%
from sklearn.model_selection import GridSearchCV
classifier=DecisionTreeClassifier()

# %%
clf=GridSearchCV(classifier, param_grid=parameters, cv=5, scoring='accuracy', verbose=3)
clf.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 90 candidates, totalling 450 fits
# [CV 1/5] END criterion=gini, max_depth=1, max_features=auto, splitter=best;, score=nan total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=1, max_features=auto, splitter=best;, score=nan total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=1, max_features=auto, splitter=best;, score=nan total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=1, max_features=auto, splitter=best;, score=nan total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=1, max_features=auto, splitter=best;, score=nan total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=1, max_features=auto, splitter=random;, score=nan total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=1, max_features=auto, splitter=random;, score=nan total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=1, max_features=auto, splitter=random;, score=nan total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=1, max_features=auto, splitter=random;, score=nan total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=1, max_features=auto, splitter=random;, score=nan total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=1, max_features=sqrt, splitter=best;, score=0.713 total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=1, max_features=sqrt, splitter=best;, score=0.653 total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=1, max_features=sqrt, splitter=best;, score=0.653 total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=1, max_features=sqrt, splitter=best;, score=0.705 total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=1, max_features=sqrt, splitter=best;, score=0.651 total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=1, max_features=sqrt, splitter=random;, score=0.647 total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=1, max_features=sqrt, splitter=random;, score=0.653 total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=1, max_features=sqrt, splitter=random;, score=0.653 total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=1, max_features=sqrt, splitter=random;, score=0.651 total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=1, max_features=sqrt, splitter=random;, score=0.617 total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=1, max_features=log2, splitter=best;, score=0.647 total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=1, max_features=log2, splitter=best;, score=0.653 total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=1, max_features=log2, splitter=best;, score=0.653 total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=1, max_features=log2, splitter=best;, score=0.685 total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=1, max_features=log2, splitter=best;, score=0.651 total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=1, max_features=log2, splitter=random;, score=0.647 total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=1, max_features=log2, splitter=random;, score=0.653 total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=1, max_features=log2, splitter=random;, score=0.660 total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=1, max_features=log2, splitter=random;, score=0.671 total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=1, max_features=log2, splitter=random;, score=0.685 total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=2, max_features=auto, splitter=best;, score=nan total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=2, max_features=auto, splitter=best;, score=nan total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=2, max_features=auto, splitter=best;, score=nan total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=2, max_features=auto, splitter=best;, score=nan total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=2, max_features=auto, splitter=best;, score=nan total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=2, max_features=auto, splitter=random;, score=nan total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=2, max_features=auto, splitter=random;, score=nan total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=2, max_features=auto, splitter=random;, score=nan total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=2, max_features=auto, splitter=random;, score=nan total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=2, max_features=auto, splitter=random;, score=nan total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=2, max_features=sqrt, splitter=best;, score=0.667 total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=2, max_features=sqrt, splitter=best;, score=0.700 total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=2, max_features=sqrt, splitter=best;, score=0.700 total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=2, max_features=sqrt, splitter=best;, score=0.664 total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=2, max_features=sqrt, splitter=best;, score=0.644 total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=2, max_features=sqrt, splitter=random;, score=0.687 total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=2, max_features=sqrt, splitter=random;, score=0.647 total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=2, max_features=sqrt, splitter=random;, score=0.653 total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=2, max_features=sqrt, splitter=random;, score=0.664 total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=2, max_features=sqrt, splitter=random;, score=0.705 total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=2, max_features=log2, splitter=best;, score=0.687 total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=2, max_features=log2, splitter=best;, score=0.693 total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=2, max_features=log2, splitter=best;, score=0.707 total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=2, max_features=log2, splitter=best;, score=0.698 total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=2, max_features=log2, splitter=best;, score=0.745 total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=2, max_features=log2, splitter=random;, score=0.713 total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=2, max_features=log2, splitter=random;, score=0.707 total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=2, max_features=log2, splitter=random;, score=0.633 total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=2, max_features=log2, splitter=random;, score=0.772 total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=2, max_features=log2, splitter=random;, score=0.658 total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=3, max_features=auto, splitter=best;, score=nan total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=3, max_features=auto, splitter=best;, score=nan total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=3, max_features=auto, splitter=best;, score=nan total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=3, max_features=auto, splitter=best;, score=nan total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=3, max_features=auto, splitter=best;, score=nan total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=3, max_features=auto, splitter=random;, score=nan total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=3, max_features=auto, splitter=random;, score=nan total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=3, max_features=auto, splitter=random;, score=nan total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=3, max_features=auto, splitter=random;, score=nan total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=3, max_features=auto, splitter=random;, score=nan total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=3, max_features=sqrt, splitter=best;, score=0.667 total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=3, max_features=sqrt, splitter=best;, score=0.707 total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=3, max_features=sqrt, splitter=best;, score=0.700 total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=3, max_features=sqrt, splitter=best;, score=0.765 total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=3, max_features=sqrt, splitter=best;, score=0.644 total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=3, max_features=sqrt, splitter=random;, score=0.687 total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=3, max_features=sqrt, splitter=random;, score=0.647 total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=3, max_features=sqrt, splitter=random;, score=0.660 total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=3, max_features=sqrt, splitter=random;, score=0.711 total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=3, max_features=sqrt, splitter=random;, score=0.705 total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=3, max_features=log2, splitter=best;, score=0.707 total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=3, max_features=log2, splitter=best;, score=0.660 total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=3, max_features=log2, splitter=best;, score=0.693 total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=3, max_features=log2, splitter=best;, score=0.711 total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=3, max_features=log2, splitter=best;, score=0.732 total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=3, max_features=log2, splitter=random;, score=0.707 total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=3, max_features=log2, splitter=random;, score=0.767 total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=3, max_features=log2, splitter=random;, score=0.727 total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=3, max_features=log2, splitter=random;, score=0.765 total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=3, max_features=log2, splitter=random;, score=0.698 total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=4, max_features=auto, splitter=best;, score=nan total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=4, max_features=auto, splitter=best;, score=nan total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=4, max_features=auto, splitter=best;, score=nan total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=4, max_features=auto, splitter=best;, score=nan total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=4, max_features=auto, splitter=best;, score=nan total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=4, max_features=auto, splitter=random;, score=nan total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=4, max_features=auto, splitter=random;, score=nan total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=4, max_features=auto, splitter=random;, score=nan total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=4, max_features=auto, splitter=random;, score=nan total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=4, max_features=auto, splitter=random;, score=nan total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=4, max_features=sqrt, splitter=best;, score=0.700 total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=4, max_features=sqrt, splitter=best;, score=0.680 total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=4, max_features=sqrt, splitter=best;, score=0.733 total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=4, max_features=sqrt, splitter=best;, score=0.705 total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=4, max_features=sqrt, splitter=best;, score=0.732 total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=4, max_features=sqrt, splitter=random;, score=0.720 total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=4, max_features=sqrt, splitter=random;, score=0.667 total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=4, max_features=sqrt, splitter=random;, score=0.673 total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=4, max_features=sqrt, splitter=random;, score=0.772 total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=4, max_features=sqrt, splitter=random;, score=0.671 total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=4, max_features=log2, splitter=best;, score=0.733 total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=4, max_features=log2, splitter=best;, score=0.640 total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=4, max_features=log2, splitter=best;, score=0.707 total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=4, max_features=log2, splitter=best;, score=0.691 total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=4, max_features=log2, splitter=best;, score=0.691 total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=4, max_features=log2, splitter=random;, score=0.653 total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=4, max_features=log2, splitter=random;, score=0.740 total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=4, max_features=log2, splitter=random;, score=0.733 total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=4, max_features=log2, splitter=random;, score=0.691 total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=4, max_features=log2, splitter=random;, score=0.691 total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=5, max_features=auto, splitter=best;, score=nan total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=5, max_features=auto, splitter=best;, score=nan total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=5, max_features=auto, splitter=best;, score=nan total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=5, max_features=auto, splitter=best;, score=nan total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=5, max_features=auto, splitter=best;, score=nan total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=5, max_features=auto, splitter=random;, score=nan total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=5, max_features=auto, splitter=random;, score=nan total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=5, max_features=auto, splitter=random;, score=nan total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=5, max_features=auto, splitter=random;, score=nan total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=5, max_features=auto, splitter=random;, score=nan total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=5, max_features=sqrt, splitter=best;, score=0.687 total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=5, max_features=sqrt, splitter=best;, score=0.653 total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=5, max_features=sqrt, splitter=best;, score=0.787 total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=5, max_features=sqrt, splitter=best;, score=0.765 total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=5, max_features=sqrt, splitter=best;, score=0.651 total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=5, max_features=sqrt, splitter=random;, score=0.720 total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=5, max_features=sqrt, splitter=random;, score=0.673 total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=5, max_features=sqrt, splitter=random;, score=0.727 total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=5, max_features=sqrt, splitter=random;, score=0.664 total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=5, max_features=sqrt, splitter=random;, score=0.671 total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=5, max_features=log2, splitter=best;, score=0.793 total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=5, max_features=log2, splitter=best;, score=0.760 total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=5, max_features=log2, splitter=best;, score=0.787 total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=5, max_features=log2, splitter=best;, score=0.745 total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=5, max_features=log2, splitter=best;, score=0.691 total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=5, max_features=log2, splitter=random;, score=0.707 total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=5, max_features=log2, splitter=random;, score=0.720 total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=5, max_features=log2, splitter=random;, score=0.760 total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=5, max_features=log2, splitter=random;, score=0.691 total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=5, max_features=log2, splitter=random;, score=0.738 total time=   0.0s
# [CV 1/5] END criterion=entropy, max_depth=1, max_features=auto, splitter=best;, score=nan total time=   0.0s
# [CV 2/5] END criterion=entropy, max_depth=1, max_features=auto, splitter=best;, score=nan total time=   0.0s
# [CV 3/5] END criterion=entropy, max_depth=1, max_features=auto, splitter=best;, score=nan total time=   0.0s
# [CV 4/5] END criterion=entropy, max_depth=1, max_features=auto, splitter=best;, score=nan total time=   0.0s
# [CV 5/5] END criterion=entropy, max_depth=1, max_features=auto, splitter=best;, score=nan total time=   0.0s
# [CV 1/5] END criterion=entropy, max_depth=1, max_features=auto, splitter=random;, score=nan total time=   0.0s
# [CV 2/5] END criterion=entropy, max_depth=1, max_features=auto, splitter=random;, score=nan total time=   0.0s
# [CV 3/5] END criterion=entropy, max_depth=1, max_features=auto, splitter=random;, score=nan total time=   0.0s
# [CV 4/5] END criterion=entropy, max_depth=1, max_features=auto, splitter=random;, score=nan total time=   0.0s
# [CV 5/5] END criterion=entropy, max_depth=1, max_features=auto, splitter=random;, score=nan total time=   0.0s
# [CV 1/5] END criterion=entropy, max_depth=1, max_features=sqrt, splitter=best;, score=0.647 total time=   0.0s
# [CV 2/5] END criterion=entropy, max_depth=1, max_features=sqrt, splitter=best;, score=0.707 total time=   0.0s
# [CV 3/5] END criterion=entropy, max_depth=1, max_features=sqrt, splitter=best;, score=0.700 total time=   0.0s
# [CV 4/5] END criterion=entropy, max_depth=1, max_features=sqrt, splitter=best;, score=0.651 total time=   0.0s
# [CV 5/5] END criterion=entropy, max_depth=1, max_features=sqrt, splitter=best;, score=0.651 total time=   0.0s
# [CV 1/5] END criterion=entropy, max_depth=1, max_features=sqrt, splitter=random;, score=0.647 total time=   0.0s
# [CV 2/5] END criterion=entropy, max_depth=1, max_features=sqrt, splitter=random;, score=0.633 total time=   0.0s
# [CV 3/5] END criterion=entropy, max_depth=1, max_features=sqrt, splitter=random;, score=0.700 total time=   0.0s
# [CV 4/5] END criterion=entropy, max_depth=1, max_features=sqrt, splitter=random;, score=0.738 total time=   0.0s
# [CV 5/5] END criterion=entropy, max_depth=1, max_features=sqrt, splitter=random;, score=0.658 total time=   0.0s
# [CV 1/5] END criterion=entropy, max_depth=1, max_features=log2, splitter=best;, score=0.647 total time=   0.0s
# [CV 2/5] END criterion=entropy, max_depth=1, max_features=log2, splitter=best;, score=0.707 total time=   0.0s
# [CV 3/5] END criterion=entropy, max_depth=1, max_features=log2, splitter=best;, score=0.700 total time=   0.0s
# [CV 4/5] END criterion=entropy, max_depth=1, max_features=log2, splitter=best;, score=0.705 total time=   0.0s
# [CV 5/5] END criterion=entropy, max_depth=1, max_features=log2, splitter=best;, score=0.698 total time=   0.0s
# [CV 1/5] END criterion=entropy, max_depth=1, max_features=log2, splitter=random;, score=0.700 total time=   0.0s
# [CV 2/5] END criterion=entropy, max_depth=1, max_features=log2, splitter=random;, score=0.653 total time=   0.0s
# [CV 3/5] END criterion=entropy, max_depth=1, max_features=log2, splitter=random;, score=0.673 total time=   0.0s
# [CV 4/5] END criterion=entropy, max_depth=1, max_features=log2, splitter=random;, score=0.651 total time=   0.0s
# [CV 5/5] END criterion=entropy, max_depth=1, max_features=log2, splitter=random;, score=0.624 total time=   0.0s
# [CV 1/5] END criterion=entropy, max_depth=2, max_features=auto, splitter=best;, score=nan total time=   0.0s
# [CV 2/5] END criterion=entropy, max_depth=2, max_features=auto, splitter=best;, score=nan total time=   0.0s
# [CV 3/5] END criterion=entropy, max_depth=2, max_features=auto, splitter=best;, score=nan total time=   0.0s
# [CV 4/5] END criterion=entropy, max_depth=2, max_features=auto, splitter=best;, score=nan total time=   0.0s
# [CV 5/5] END criterion=entropy, max_depth=2, max_features=auto, splitter=best;, score=nan total time=   0.0s
# [CV 1/5] END criterion=entropy, max_depth=2, max_features=auto, splitter=random;, score=nan total time=   0.0s
# [CV 2/5] END criterion=entropy, max_depth=2, max_features=auto, splitter=random;, score=nan total time=   0.0s
# [CV 3/5] END criterion=entropy, max_depth=2, max_features=auto, splitter=random;, score=nan total time=   0.0s
# [CV 4/5] END criterion=entropy, max_depth=2, max_features=auto, splitter=random;, score=nan total time=   0.0s
# [CV 5/5] END criterion=entropy, max_depth=2, max_features=auto, splitter=random;, score=nan total time=   0.0s
# [CV 1/5] END criterion=entropy, max_depth=2, max_features=sqrt, splitter=best;, score=0.680 total time=   0.0s
# [CV 2/5] END criterion=entropy, max_depth=2, max_features=sqrt, splitter=best;, score=0.693 total time=   0.0s
# [CV 3/5] END criterion=entropy, max_depth=2, max_features=sqrt, splitter=best;, score=0.607 total time=   0.0s
# [CV 4/5] END criterion=entropy, max_depth=2, max_features=sqrt, splitter=best;, score=0.705 total time=   0.0s
# [CV 5/5] END criterion=entropy, max_depth=2, max_features=sqrt, splitter=best;, score=0.718 total time=   0.0s
# [CV 1/5] END criterion=entropy, max_depth=2, max_features=sqrt, splitter=random;, score=0.627 total time=   0.0s
# [CV 2/5] END criterion=entropy, max_depth=2, max_features=sqrt, splitter=random;, score=0.647 total time=   0.0s
# [CV 3/5] END criterion=entropy, max_depth=2, max_features=sqrt, splitter=random;, score=0.673 total time=   0.0s
# [CV 4/5] END criterion=entropy, max_depth=2, max_features=sqrt, splitter=random;, score=0.651 total time=   0.0s
# [CV 5/5] END criterion=entropy, max_depth=2, max_features=sqrt, splitter=random;, score=0.664 total time=   0.0s
# [CV 1/5] END criterion=entropy, max_depth=2, max_features=log2, splitter=best;, score=0.660 total time=   0.0s
# [CV 2/5] END criterion=entropy, max_depth=2, max_features=log2, splitter=best;, score=0.707 total time=   0.0s
# [CV 3/5] END criterion=entropy, max_depth=2, max_features=log2, splitter=best;, score=0.667 total time=   0.0s
# [CV 4/5] END criterion=entropy, max_depth=2, max_features=log2, splitter=best;, score=0.718 total time=   0.0s
# [CV 5/5] END criterion=entropy, max_depth=2, max_features=log2, splitter=best;, score=0.678 total time=   0.0s
# [CV 1/5] END criterion=entropy, max_depth=2, max_features=log2, splitter=random;, score=0.667 total time=   0.0s
# [CV 2/5] END criterion=entropy, max_depth=2, max_features=log2, splitter=random;, score=0.667 total time=   0.0s
# [CV 3/5] END criterion=entropy, max_depth=2, max_features=log2, splitter=random;, score=0.680 total time=   0.0s
# [CV 4/5] END criterion=entropy, max_depth=2, max_features=log2, splitter=random;, score=0.671 total time=   0.0s
# [CV 5/5] END criterion=entropy, max_depth=2, max_features=log2, splitter=random;, score=0.685 total time=   0.0s
# [CV 1/5] END criterion=entropy, max_depth=3, max_features=auto, splitter=best;, score=nan total time=   0.0s
# [CV 2/5] END criterion=entropy, max_depth=3, max_features=auto, splitter=best;, score=nan total time=   0.0s
# [CV 3/5] END criterion=entropy, max_depth=3, max_features=auto, splitter=best;, score=nan total time=   0.0s
# [CV 4/5] END criterion=entropy, max_depth=3, max_features=auto, splitter=best;, score=nan total time=   0.0s
# [CV 5/5] END criterion=entropy, max_depth=3, max_features=auto, splitter=best;, score=nan total time=   0.0s
# [CV 1/5] END criterion=entropy, max_depth=3, max_features=auto, splitter=random;, score=nan total time=   0.0s
# [CV 2/5] END criterion=entropy, max_depth=3, max_features=auto, splitter=random;, score=nan total time=   0.0s
# [CV 3/5] END criterion=entropy, max_depth=3, max_features=auto, splitter=random;, score=nan total time=   0.0s
# [CV 4/5] END criterion=entropy, max_depth=3, max_features=auto, splitter=random;, score=nan total time=   0.0s
# [CV 5/5] END criterion=entropy, max_depth=3, max_features=auto, splitter=random;, score=nan total time=   0.0s
# [CV 1/5] END criterion=entropy, max_depth=3, max_features=sqrt, splitter=best;, score=0.707 total time=   0.0s
# [CV 2/5] END criterion=entropy, max_depth=3, max_features=sqrt, splitter=best;, score=0.693 total time=   0.0s
# [CV 3/5] END criterion=entropy, max_depth=3, max_features=sqrt, splitter=best;, score=0.587 total time=   0.0s
# [CV 4/5] END criterion=entropy, max_depth=3, max_features=sqrt, splitter=best;, score=0.658 total time=   0.0s
# [CV 5/5] END criterion=entropy, max_depth=3, max_features=sqrt, splitter=best;, score=0.711 total time=   0.0s
# [CV 1/5] END criterion=entropy, max_depth=3, max_features=sqrt, splitter=random;, score=0.693 total time=   0.0s
# [CV 2/5] END criterion=entropy, max_depth=3, max_features=sqrt, splitter=random;, score=0.593 total time=   0.0s
# [CV 3/5] END criterion=entropy, max_depth=3, max_features=sqrt, splitter=random;, score=0.680 total time=   0.0s
# [CV 4/5] END criterion=entropy, max_depth=3, max_features=sqrt, splitter=random;, score=0.664 total time=   0.0s
# [CV 5/5] END criterion=entropy, max_depth=3, max_features=sqrt, splitter=random;, score=0.671 total time=   0.0s
# [CV 1/5] END criterion=entropy, max_depth=3, max_features=log2, splitter=best;, score=0.687 total time=   0.0s
# [CV 2/5] END criterion=entropy, max_depth=3, max_features=log2, splitter=best;, score=0.693 total time=   0.0s
# [CV 3/5] END criterion=entropy, max_depth=3, max_features=log2, splitter=best;, score=0.740 total time=   0.0s
# [CV 4/5] END criterion=entropy, max_depth=3, max_features=log2, splitter=best;, score=0.758 total time=   0.0s
# [CV 5/5] END criterion=entropy, max_depth=3, max_features=log2, splitter=best;, score=0.711 total time=   0.0s
# [CV 1/5] END criterion=entropy, max_depth=3, max_features=log2, splitter=random;, score=0.687 total time=   0.0s
# [CV 2/5] END criterion=entropy, max_depth=3, max_features=log2, splitter=random;, score=0.633 total time=   0.0s
# [CV 3/5] END criterion=entropy, max_depth=3, max_features=log2, splitter=random;, score=0.673 total time=   0.0s
# [CV 4/5] END criterion=entropy, max_depth=3, max_features=log2, splitter=random;, score=0.705 total time=   0.0s
# [CV 5/5] END criterion=entropy, max_depth=3, max_features=log2, splitter=random;, score=0.745 total time=   0.0s
# [CV 1/5] END criterion=entropy, max_depth=4, max_features=auto, splitter=best;, score=nan total time=   0.0s
# [CV 2/5] END criterion=entropy, max_depth=4, max_features=auto, splitter=best;, score=nan total time=   0.0s
# [CV 3/5] END criterion=entropy, max_depth=4, max_features=auto, splitter=best;, score=nan total time=   0.0s
# [CV 4/5] END criterion=entropy, max_depth=4, max_features=auto, splitter=best;, score=nan total time=   0.0s
# [CV 5/5] END criterion=entropy, max_depth=4, max_features=auto, splitter=best;, score=nan total time=   0.0s
# [CV 1/5] END criterion=entropy, max_depth=4, max_features=auto, splitter=random;, score=nan total time=   0.0s
# [CV 2/5] END criterion=entropy, max_depth=4, max_features=auto, splitter=random;, score=nan total time=   0.0s
# [CV 3/5] END criterion=entropy, max_depth=4, max_features=auto, splitter=random;, score=nan total time=   0.0s
# [CV 4/5] END criterion=entropy, max_depth=4, max_features=auto, splitter=random;, score=nan total time=   0.0s
# [CV 5/5] END criterion=entropy, max_depth=4, max_features=auto, splitter=random;, score=nan total time=   0.0s
# [CV 1/5] END criterion=entropy, max_depth=4, max_features=sqrt, splitter=best;, score=0.727 total time=   0.0s
# [CV 2/5] END criterion=entropy, max_depth=4, max_features=sqrt, splitter=best;, score=0.720 total time=   0.0s
# [CV 3/5] END criterion=entropy, max_depth=4, max_features=sqrt, splitter=best;, score=0.733 total time=   0.0s
# [CV 4/5] END criterion=entropy, max_depth=4, max_features=sqrt, splitter=best;, score=0.779 total time=   0.0s
# [CV 5/5] END criterion=entropy, max_depth=4, max_features=sqrt, splitter=best;, score=0.711 total time=   0.0s
# [CV 1/5] END criterion=entropy, max_depth=4, max_features=sqrt, splitter=random;, score=0.653 total time=   0.0s
# [CV 2/5] END criterion=entropy, max_depth=4, max_features=sqrt, splitter=random;, score=0.653 total time=   0.0s
# [CV 3/5] END criterion=entropy, max_depth=4, max_features=sqrt, splitter=random;, score=0.647 total time=   0.0s
# [CV 4/5] END criterion=entropy, max_depth=4, max_features=sqrt, splitter=random;, score=0.758 total time=   0.0s
# [CV 5/5] END criterion=entropy, max_depth=4, max_features=sqrt, splitter=random;, score=0.705 total time=   0.0s
# [CV 1/5] END criterion=entropy, max_depth=4, max_features=log2, splitter=best;, score=0.667 total time=   0.0s
# [CV 2/5] END criterion=entropy, max_depth=4, max_features=log2, splitter=best;, score=0.660 total time=   0.0s
# [CV 3/5] END criterion=entropy, max_depth=4, max_features=log2, splitter=best;, score=0.747 total time=   0.0s
# [CV 4/5] END criterion=entropy, max_depth=4, max_features=log2, splitter=best;, score=0.705 total time=   0.0s
# [CV 5/5] END criterion=entropy, max_depth=4, max_features=log2, splitter=best;, score=0.718 total time=   0.0s
# [CV 1/5] END criterion=entropy, max_depth=4, max_features=log2, splitter=random;, score=0.660 total time=   0.0s
# [CV 2/5] END criterion=entropy, max_depth=4, max_features=log2, splitter=random;, score=0.627 total time=   0.0s
# [CV 3/5] END criterion=entropy, max_depth=4, max_features=log2, splitter=random;, score=0.753 total time=   0.0s
# [CV 4/5] END criterion=entropy, max_depth=4, max_features=log2, splitter=random;, score=0.631 total time=   0.0s
# [CV 5/5] END criterion=entropy, max_depth=4, max_features=log2, splitter=random;, score=0.765 total time=   0.0s
# [CV 1/5] END criterion=entropy, max_depth=5, max_features=auto, splitter=best;, score=nan total time=   0.0s
# [CV 2/5] END criterion=entropy, max_depth=5, max_features=auto, splitter=best;, score=nan total time=   0.0s
# [CV 3/5] END criterion=entropy, max_depth=5, max_features=auto, splitter=best;, score=nan total time=   0.0s
# [CV 4/5] END criterion=entropy, max_depth=5, max_features=auto, splitter=best;, score=nan total time=   0.0s
# [CV 5/5] END criterion=entropy, max_depth=5, max_features=auto, splitter=best;, score=nan total time=   0.0s
# [CV 1/5] END criterion=entropy, max_depth=5, max_features=auto, splitter=random;, score=nan total time=   0.0s
# [CV 2/5] END criterion=entropy, max_depth=5, max_features=auto, splitter=random;, score=nan total time=   0.0s
# [CV 3/5] END criterion=entropy, max_depth=5, max_features=auto, splitter=random;, score=nan total time=   0.0s
# [CV 4/5] END criterion=entropy, max_depth=5, max_features=auto, splitter=random;, score=nan total time=   0.0s
# [CV 5/5] END criterion=entropy, max_depth=5, max_features=auto, splitter=random;, score=nan total time=   0.0s
# [CV 1/5] END criterion=entropy, max_depth=5, max_features=sqrt, splitter=best;, score=0.753 total time=   0.0s
# [CV 2/5] END criterion=entropy, max_depth=5, max_features=sqrt, splitter=best;, score=0.720 total time=   0.0s
# [CV 3/5] END criterion=entropy, max_depth=5, max_features=sqrt, splitter=best;, score=0.587 total time=   0.0s
# [CV 4/5] END criterion=entropy, max_depth=5, max_features=sqrt, splitter=best;, score=0.752 total time=   0.0s
# [CV 5/5] END criterion=entropy, max_depth=5, max_features=sqrt, splitter=best;, score=0.698 total time=   0.0s
# [CV 1/5] END criterion=entropy, max_depth=5, max_features=sqrt, splitter=random;, score=0.640 total time=   0.0s
# [CV 2/5] END criterion=entropy, max_depth=5, max_features=sqrt, splitter=random;, score=0.700 total time=   0.0s
# [CV 3/5] END criterion=entropy, max_depth=5, max_features=sqrt, splitter=random;, score=0.667 total time=   0.0s
# [CV 4/5] END criterion=entropy, max_depth=5, max_features=sqrt, splitter=random;, score=0.664 total time=   0.0s
# [CV 5/5] END criterion=entropy, max_depth=5, max_features=sqrt, splitter=random;, score=0.685 total time=   0.0s
# [CV 1/5] END criterion=entropy, max_depth=5, max_features=log2, splitter=best;, score=0.700 total time=   0.0s
# [CV 2/5] END criterion=entropy, max_depth=5, max_features=log2, splitter=best;, score=0.713 total time=   0.0s
# [CV 3/5] END criterion=entropy, max_depth=5, max_features=log2, splitter=best;, score=0.740 total time=   0.0s
# [CV 4/5] END criterion=entropy, max_depth=5, max_features=log2, splitter=best;, score=0.651 total time=   0.0s
# [CV 5/5] END criterion=entropy, max_depth=5, max_features=log2, splitter=best;, score=0.738 total time=   0.0s
# [CV 1/5] END criterion=entropy, max_depth=5, max_features=log2, splitter=random;, score=0.640 total time=   0.0s
# [CV 2/5] END criterion=entropy, max_depth=5, max_features=log2, splitter=random;, score=0.753 total time=   0.0s
# [CV 3/5] END criterion=entropy, max_depth=5, max_features=log2, splitter=random;, score=0.727 total time=   0.0s
# [CV 4/5] END criterion=entropy, max_depth=5, max_features=log2, splitter=random;, score=0.658 total time=   0.0s
# [CV 5/5] END criterion=entropy, max_depth=5, max_features=log2, splitter=random;, score=0.725 total time=   0.0s
# [CV 1/5] END criterion=log_loss, max_depth=1, max_features=auto, splitter=best;, score=nan total time=   0.0s
# [CV 2/5] END criterion=log_loss, max_depth=1, max_features=auto, splitter=best;, score=nan total time=   0.0s
# [CV 3/5] END criterion=log_loss, max_depth=1, max_features=auto, splitter=best;, score=nan total time=   0.0s
# [CV 4/5] END criterion=log_loss, max_depth=1, max_features=auto, splitter=best;, score=nan total time=   0.0s
# [CV 5/5] END criterion=log_loss, max_depth=1, max_features=auto, splitter=best;, score=nan total time=   0.0s
# [CV 1/5] END criterion=log_loss, max_depth=1, max_features=auto, splitter=random;, score=nan total time=   0.0s
# [CV 2/5] END criterion=log_loss, max_depth=1, max_features=auto, splitter=random;, score=nan total time=   0.0s
# [CV 3/5] END criterion=log_loss, max_depth=1, max_features=auto, splitter=random;, score=nan total time=   0.0s
# [CV 4/5] END criterion=log_loss, max_depth=1, max_features=auto, splitter=random;, score=nan total time=   0.0s
# [CV 5/5] END criterion=log_loss, max_depth=1, max_features=auto, splitter=random;, score=nan total time=   0.0s
# [CV 1/5] END criterion=log_loss, max_depth=1, max_features=sqrt, splitter=best;, score=0.647 total time=   0.0s
# [CV 2/5] END criterion=log_loss, max_depth=1, max_features=sqrt, splitter=best;, score=0.653 total time=   0.0s
# [CV 3/5] END criterion=log_loss, max_depth=1, max_features=sqrt, splitter=best;, score=0.700 total time=   0.0s
# [CV 4/5] END criterion=log_loss, max_depth=1, max_features=sqrt, splitter=best;, score=0.651 total time=   0.0s
# [CV 5/5] END criterion=log_loss, max_depth=1, max_features=sqrt, splitter=best;, score=0.651 total time=   0.0s
# [CV 1/5] END criterion=log_loss, max_depth=1, max_features=sqrt, splitter=random;, score=0.647 total time=   0.0s
# [CV 2/5] END criterion=log_loss, max_depth=1, max_features=sqrt, splitter=random;, score=0.627 total time=   0.0s
# [CV 3/5] END criterion=log_loss, max_depth=1, max_features=sqrt, splitter=random;, score=0.627 total time=   0.0s
# [CV 4/5] END criterion=log_loss, max_depth=1, max_features=sqrt, splitter=random;, score=0.651 total time=   0.0s
# [CV 5/5] END criterion=log_loss, max_depth=1, max_features=sqrt, splitter=random;, score=0.651 total time=   0.0s
# [CV 1/5] END criterion=log_loss, max_depth=1, max_features=log2, splitter=best;, score=0.687 total time=   0.0s
# [CV 2/5] END criterion=log_loss, max_depth=1, max_features=log2, splitter=best;, score=0.653 total time=   0.0s
# [CV 3/5] END criterion=log_loss, max_depth=1, max_features=log2, splitter=best;, score=0.653 total time=   0.0s
# [CV 4/5] END criterion=log_loss, max_depth=1, max_features=log2, splitter=best;, score=0.651 total time=   0.0s
# [CV 5/5] END criterion=log_loss, max_depth=1, max_features=log2, splitter=best;, score=0.651 total time=   0.0s
# [CV 1/5] END criterion=log_loss, max_depth=1, max_features=log2, splitter=random;, score=0.713 total time=   0.0s
# [CV 2/5] END criterion=log_loss, max_depth=1, max_features=log2, splitter=random;, score=0.653 total time=   0.0s
# [CV 3/5] END criterion=log_loss, max_depth=1, max_features=log2, splitter=random;, score=0.653 total time=   0.0s
# [CV 4/5] END criterion=log_loss, max_depth=1, max_features=log2, splitter=random;, score=0.664 total time=   0.0s
# [CV 5/5] END criterion=log_loss, max_depth=1, max_features=log2, splitter=random;, score=0.651 total time=   0.0s
# [CV 1/5] END criterion=log_loss, max_depth=2, max_features=auto, splitter=best;, score=nan total time=   0.0s
# [CV 2/5] END criterion=log_loss, max_depth=2, max_features=auto, splitter=best;, score=nan total time=   0.0s
# [CV 3/5] END criterion=log_loss, max_depth=2, max_features=auto, splitter=best;, score=nan total time=   0.0s
# [CV 4/5] END criterion=log_loss, max_depth=2, max_features=auto, splitter=best;, score=nan total time=   0.0s
# [CV 5/5] END criterion=log_loss, max_depth=2, max_features=auto, splitter=best;, score=nan total time=   0.0s
# [CV 1/5] END criterion=log_loss, max_depth=2, max_features=auto, splitter=random;, score=nan total time=   0.0s
# [CV 2/5] END criterion=log_loss, max_depth=2, max_features=auto, splitter=random;, score=nan total time=   0.0s
# [CV 3/5] END criterion=log_loss, max_depth=2, max_features=auto, splitter=random;, score=nan total time=   0.0s
# [CV 4/5] END criterion=log_loss, max_depth=2, max_features=auto, splitter=random;, score=nan total time=   0.0s
# [CV 5/5] END criterion=log_loss, max_depth=2, max_features=auto, splitter=random;, score=nan total time=   0.0s
# [CV 1/5] END criterion=log_loss, max_depth=2, max_features=sqrt, splitter=best;, score=0.720 total time=   0.0s
# [CV 2/5] END criterion=log_loss, max_depth=2, max_features=sqrt, splitter=best;, score=0.627 total time=   0.0s
# [CV 3/5] END criterion=log_loss, max_depth=2, max_features=sqrt, splitter=best;, score=0.740 total time=   0.0s
# [CV 4/5] END criterion=log_loss, max_depth=2, max_features=sqrt, splitter=best;, score=0.685 total time=   0.0s
# [CV 5/5] END criterion=log_loss, max_depth=2, max_features=sqrt, splitter=best;, score=0.705 total time=   0.0s
# [CV 1/5] END criterion=log_loss, max_depth=2, max_features=sqrt, splitter=random;, score=0.700 total time=   0.0s
# [CV 2/5] END criterion=log_loss, max_depth=2, max_features=sqrt, splitter=random;, score=0.653 total time=   0.0s
# [CV 3/5] END criterion=log_loss, max_depth=2, max_features=sqrt, splitter=random;, score=0.640 total time=   0.0s
# [CV 4/5] END criterion=log_loss, max_depth=2, max_features=sqrt, splitter=random;, score=0.745 total time=   0.0s
# [CV 5/5] END criterion=log_loss, max_depth=2, max_features=sqrt, splitter=random;, score=0.691 total time=   0.0s
# [CV 1/5] END criterion=log_loss, max_depth=2, max_features=log2, splitter=best;, score=0.660 total time=   0.0s
# [CV 2/5] END criterion=log_loss, max_depth=2, max_features=log2, splitter=best;, score=0.693 total time=   0.0s
# [CV 3/5] END criterion=log_loss, max_depth=2, max_features=log2, splitter=best;, score=0.653 total time=   0.0s
# [CV 4/5] END criterion=log_loss, max_depth=2, max_features=log2, splitter=best;, score=0.671 total time=   0.0s
# [CV 5/5] END criterion=log_loss, max_depth=2, max_features=log2, splitter=best;, score=0.745 total time=   0.0s
# [CV 1/5] END criterion=log_loss, max_depth=2, max_features=log2, splitter=random;, score=0.673 total time=   0.0s
# [CV 2/5] END criterion=log_loss, max_depth=2, max_features=log2, splitter=random;, score=0.653 total time=   0.0s
# [CV 3/5] END criterion=log_loss, max_depth=2, max_features=log2, splitter=random;, score=0.767 total time=   0.0s
# [CV 4/5] END criterion=log_loss, max_depth=2, max_features=log2, splitter=random;, score=0.752 total time=   0.0s
# [CV 5/5] END criterion=log_loss, max_depth=2, max_features=log2, splitter=random;, score=0.738 total time=   0.0s
# [CV 1/5] END criterion=log_loss, max_depth=3, max_features=auto, splitter=best;, score=nan total time=   0.0s
# [CV 2/5] END criterion=log_loss, max_depth=3, max_features=auto, splitter=best;, score=nan total time=   0.0s
# [CV 3/5] END criterion=log_loss, max_depth=3, max_features=auto, splitter=best;, score=nan total time=   0.0s
# [CV 4/5] END criterion=log_loss, max_depth=3, max_features=auto, splitter=best;, score=nan total time=   0.0s
# [CV 5/5] END criterion=log_loss, max_depth=3, max_features=auto, splitter=best;, score=nan total time=   0.0s
# [CV 1/5] END criterion=log_loss, max_depth=3, max_features=auto, splitter=random;, score=nan total time=   0.0s
# [CV 2/5] END criterion=log_loss, max_depth=3, max_features=auto, splitter=random;, score=nan total time=   0.0s
# [CV 3/5] END criterion=log_loss, max_depth=3, max_features=auto, splitter=random;, score=nan total time=   0.0s
# [CV 4/5] END criterion=log_loss, max_depth=3, max_features=auto, splitter=random;, score=nan total time=   0.0s
# [CV 5/5] END criterion=log_loss, max_depth=3, max_features=auto, splitter=random;, score=nan total time=   0.0s
# [CV 1/5] END criterion=log_loss, max_depth=3, max_features=sqrt, splitter=best;, score=0.640 total time=   0.0s
# [CV 2/5] END criterion=log_loss, max_depth=3, max_features=sqrt, splitter=best;, score=0.693 total time=   0.0s
# [CV 3/5] END criterion=log_loss, max_depth=3, max_features=sqrt, splitter=best;, score=0.707 total time=   0.0s
# [CV 4/5] END criterion=log_loss, max_depth=3, max_features=sqrt, splitter=best;, score=0.651 total time=   0.0s
# [CV 5/5] END criterion=log_loss, max_depth=3, max_features=sqrt, splitter=best;, score=0.691 total time=   0.0s
# [CV 1/5] END criterion=log_loss, max_depth=3, max_features=sqrt, splitter=random;, score=0.640 total time=   0.0s
# [CV 2/5] END criterion=log_loss, max_depth=3, max_features=sqrt, splitter=random;, score=0.673 total time=   0.0s
# [CV 3/5] END criterion=log_loss, max_depth=3, max_features=sqrt, splitter=random;, score=0.753 total time=   0.0s
# [CV 4/5] END criterion=log_loss, max_depth=3, max_features=sqrt, splitter=random;, score=0.644 total time=   0.0s
# [CV 5/5] END criterion=log_loss, max_depth=3, max_features=sqrt, splitter=random;, score=0.651 total time=   0.0s
# [CV 1/5] END criterion=log_loss, max_depth=3, max_features=log2, splitter=best;, score=0.713 total time=   0.0s
# [CV 2/5] END criterion=log_loss, max_depth=3, max_features=log2, splitter=best;, score=0.700 total time=   0.0s
# [CV 3/5] END criterion=log_loss, max_depth=3, max_features=log2, splitter=best;, score=0.713 total time=   0.0s
# [CV 4/5] END criterion=log_loss, max_depth=3, max_features=log2, splitter=best;, score=0.758 total time=   0.0s
# [CV 5/5] END criterion=log_loss, max_depth=3, max_features=log2, splitter=best;, score=0.725 total time=   0.0s
# [CV 1/5] END criterion=log_loss, max_depth=3, max_features=log2, splitter=random;, score=0.627 total time=   0.0s
# [CV 2/5] END criterion=log_loss, max_depth=3, max_features=log2, splitter=random;, score=0.687 total time=   0.0s
# [CV 3/5] END criterion=log_loss, max_depth=3, max_features=log2, splitter=random;, score=0.760 total time=   0.0s
# [CV 4/5] END criterion=log_loss, max_depth=3, max_features=log2, splitter=random;, score=0.685 total time=   0.0s
# [CV 5/5] END criterion=log_loss, max_depth=3, max_features=log2, splitter=random;, score=0.711 total time=   0.0s
# [CV 1/5] END criterion=log_loss, max_depth=4, max_features=auto, splitter=best;, score=nan total time=   0.0s
# [CV 2/5] END criterion=log_loss, max_depth=4, max_features=auto, splitter=best;, score=nan total time=   0.0s
# [CV 3/5] END criterion=log_loss, max_depth=4, max_features=auto, splitter=best;, score=nan total time=   0.0s
# [CV 4/5] END criterion=log_loss, max_depth=4, max_features=auto, splitter=best;, score=nan total time=   0.0s
# [CV 5/5] END criterion=log_loss, max_depth=4, max_features=auto, splitter=best;, score=nan total time=   0.0s
# [CV 1/5] END criterion=log_loss, max_depth=4, max_features=auto, splitter=random;, score=nan total time=   0.0s
# [CV 2/5] END criterion=log_loss, max_depth=4, max_features=auto, splitter=random;, score=nan total time=   0.0s
# [CV 3/5] END criterion=log_loss, max_depth=4, max_features=auto, splitter=random;, score=nan total time=   0.0s
# [CV 4/5] END criterion=log_loss, max_depth=4, max_features=auto, splitter=random;, score=nan total time=   0.0s
# [CV 5/5] END criterion=log_loss, max_depth=4, max_features=auto, splitter=random;, score=nan total time=   0.0s
# [CV 1/5] END criterion=log_loss, max_depth=4, max_features=sqrt, splitter=best;, score=0.693 total time=   0.0s
# [CV 2/5] END criterion=log_loss, max_depth=4, max_features=sqrt, splitter=best;, score=0.673 total time=   0.0s
# [CV 3/5] END criterion=log_loss, max_depth=4, max_features=sqrt, splitter=best;, score=0.707 total time=   0.0s
# [CV 4/5] END criterion=log_loss, max_depth=4, max_features=sqrt, splitter=best;, score=0.765 total time=   0.0s
# [CV 5/5] END criterion=log_loss, max_depth=4, max_features=sqrt, splitter=best;, score=0.725 total time=   0.0s
# [CV 1/5] END criterion=log_loss, max_depth=4, max_features=sqrt, splitter=random;, score=0.687 total time=   0.0s
# [CV 2/5] END criterion=log_loss, max_depth=4, max_features=sqrt, splitter=random;, score=0.653 total time=   0.0s
# [CV 3/5] END criterion=log_loss, max_depth=4, max_features=sqrt, splitter=random;, score=0.693 total time=   0.0s
# [CV 4/5] END criterion=log_loss, max_depth=4, max_features=sqrt, splitter=random;, score=0.698 total time=   0.0s
# [CV 5/5] END criterion=log_loss, max_depth=4, max_features=sqrt, splitter=random;, score=0.678 total time=   0.0s
# [CV 1/5] END criterion=log_loss, max_depth=4, max_features=log2, splitter=best;, score=0.713 total time=   0.0s
# [CV 2/5] END criterion=log_loss, max_depth=4, max_features=log2, splitter=best;, score=0.713 total time=   0.0s
# [CV 3/5] END criterion=log_loss, max_depth=4, max_features=log2, splitter=best;, score=0.753 total time=   0.0s
# [CV 4/5] END criterion=log_loss, max_depth=4, max_features=log2, splitter=best;, score=0.685 total time=   0.0s
# [CV 5/5] END criterion=log_loss, max_depth=4, max_features=log2, splitter=best;, score=0.698 total time=   0.0s
# [CV 1/5] END criterion=log_loss, max_depth=4, max_features=log2, splitter=random;, score=0.647 total time=   0.0s
# [CV 2/5] END criterion=log_loss, max_depth=4, max_features=log2, splitter=random;, score=0.693 total time=   0.0s
# [CV 3/5] END criterion=log_loss, max_depth=4, max_features=log2, splitter=random;, score=0.713 total time=   0.0s
# [CV 4/5] END criterion=log_loss, max_depth=4, max_features=log2, splitter=random;, score=0.718 total time=   0.0s
# [CV 5/5] END criterion=log_loss, max_depth=4, max_features=log2, splitter=random;, score=0.732 total time=   0.0s
# [CV 1/5] END criterion=log_loss, max_depth=5, max_features=auto, splitter=best;, score=nan total time=   0.0s
# [CV 2/5] END criterion=log_loss, max_depth=5, max_features=auto, splitter=best;, score=nan total time=   0.0s
# [CV 3/5] END criterion=log_loss, max_depth=5, max_features=auto, splitter=best;, score=nan total time=   0.0s
# [CV 4/5] END criterion=log_loss, max_depth=5, max_features=auto, splitter=best;, score=nan total time=   0.0s
# [CV 5/5] END criterion=log_loss, max_depth=5, max_features=auto, splitter=best;, score=nan total time=   0.0s
# [CV 1/5] END criterion=log_loss, max_depth=5, max_features=auto, splitter=random;, score=nan total time=   0.0s
# [CV 2/5] END criterion=log_loss, max_depth=5, max_features=auto, splitter=random;, score=nan total time=   0.0s
# [CV 3/5] END criterion=log_loss, max_depth=5, max_features=auto, splitter=random;, score=nan total time=   0.0s
# [CV 4/5] END criterion=log_loss, max_depth=5, max_features=auto, splitter=random;, score=nan total time=   0.0s
# [CV 5/5] END criterion=log_loss, max_depth=5, max_features=auto, splitter=random;, score=nan total time=   0.0s
# [CV 1/5] END criterion=log_loss, max_depth=5, max_features=sqrt, splitter=best;, score=0.687 total time=   0.0s
# [CV 2/5] END criterion=log_loss, max_depth=5, max_features=sqrt, splitter=best;, score=0.653 total time=   0.0s
# [CV 3/5] END criterion=log_loss, max_depth=5, max_features=sqrt, splitter=best;, score=0.753 total time=   0.0s
# [CV 4/5] END criterion=log_loss, max_depth=5, max_features=sqrt, splitter=best;, score=0.711 total time=   0.0s
# [CV 5/5] END criterion=log_loss, max_depth=5, max_features=sqrt, splitter=best;, score=0.685 total time=   0.0s
# [CV 1/5] END criterion=log_loss, max_depth=5, max_features=sqrt, splitter=random;, score=0.680 total time=   0.0s
# [CV 2/5] END criterion=log_loss, max_depth=5, max_features=sqrt, splitter=random;, score=0.653 total time=   0.0s
# [CV 3/5] END criterion=log_loss, max_depth=5, max_features=sqrt, splitter=random;, score=0.733 total time=   0.0s
# [CV 4/5] END criterion=log_loss, max_depth=5, max_features=sqrt, splitter=random;, score=0.678 total time=   0.0s
# [CV 5/5] END criterion=log_loss, max_depth=5, max_features=sqrt, splitter=random;, score=0.671 total time=   0.0s
# [CV 1/5] END criterion=log_loss, max_depth=5, max_features=log2, splitter=best;, score=0.687 total time=   0.0s
# [CV 2/5] END criterion=log_loss, max_depth=5, max_features=log2, splitter=best;, score=0.760 total time=   0.0s
# [CV 3/5] END criterion=log_loss, max_depth=5, max_features=log2, splitter=best;, score=0.713 total time=   0.0s
# [CV 4/5] END criterion=log_loss, max_depth=5, max_features=log2, splitter=best;, score=0.732 total time=   0.0s
# [CV 5/5] END criterion=log_loss, max_depth=5, max_features=log2, splitter=best;, score=0.725 total time=   0.0s
# [CV 1/5] END criterion=log_loss, max_depth=5, max_features=log2, splitter=random;, score=0.667 total time=   0.0s
# [CV 2/5] END criterion=log_loss, max_depth=5, max_features=log2, splitter=random;, score=0.660 total time=   0.0s
# [CV 3/5] END criterion=log_loss, max_depth=5, max_features=log2, splitter=random;, score=0.760 total time=   0.0s
# [CV 4/5] END criterion=log_loss, max_depth=5, max_features=log2, splitter=random;, score=0.671 total time=   0.0s
# [CV 5/5] END criterion=log_loss, max_depth=5, max_features=log2, splitter=random;, score=0.685 total time=   0.0s
# GridSearchCV(cv=5, estimator=DecisionTreeClassifier(),
#              param_grid={'criterion': ['gini', 'entropy', 'log_loss'],
#                          'max_depth': [1, 2, 3, 4, 5],
#                          'max_features': ['auto', 'sqrt', 'log2'],
#                          'splitter': ['best', 'random']},
#              scoring='accuracy', verbose=3)

# %%
clf.best_params_
# Out:
# {'criterion': 'gini',
#  'max_depth': 5,
#  'max_features': 'log2',
#  'splitter': 'best'}

# %%
classifier2=DecisionTreeClassifier(criterion='entropy', max_depth=5, max_features='sqrt', splitter='random')

# %%
classifier2.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy', max_depth=5, max_features='sqrt',
#                        splitter='random')

# %% [markdown]
# lets see how model performs on test data

# %%
y_pred=classifier2.predict(X_test)

# %%
conf_mat=confusion_matrix(y_test, y_pred)
conf_mat
# Out:
# array([[11,  2],
#        [ 5,  2]])

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.65

# %%
import pickle
file=open('/config/workspace/Model/modelForPrediction.pkl', 'wb')
pickle.dump(classifier2, file)
file.close()

# %% [markdown]
# # Support Vector Classifier with Hyperparameter Tuning

# %%
# Defining parameter range
parm_grid={
    'C':[0.1, 1, 10, 100, 1000],
    'gamma':[1,0.1,0.01, 0.001, 0.0001],
    'kernel':['linear', 'rbf', 'polynomial']
}

# %%
grid=GridSearchCV(SVC(), param_grid=parm_grid, refit=True, cv=3, verbose=3, scoring='accuracy')

# %%
# EXECUTION TAKES MARE THAN 45 MINS
